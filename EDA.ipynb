# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import plotly.io as pio
pio.renderers.default = 'jupyterlab'

# %%
df = pd.read_csv('wineclean.csv')
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
heatmap = sns.heatmap(df[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']].corr(), vmax=.3, center=0, cmap=cmap, square=True, linewidth=0.5, cbar_kws={'shrink':.5})
fig = heatmap.get_figure()
fig.savefig('heatmap.png')

# %%
for i in df.columns:
    cat_num = df[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for fixed acidity: total = 96
# graph for volatile acidity: total = 143
# graph for citric acid: total = 80
# graph for residual sugar: total = 91
# graph for chlorides: total = 153
# graph for free sulfur dioxide: total = 60
# graph for total sulfur dioxide: total = 144
# graph for density: total = 107
# graph for pH: total = 89
# graph for sulphates: total = 96
# graph for alcohol: total = 65
# graph for quality: total = 6

# %%
for i in df.columns:
    if i != 'quality':
        print("Boxplot for %s versus quality:" % (i))
        chart = sns.boxplot(df['quality'], y=df[i])
        plt.show()
# Out:
# Boxplot for fixed acidity versus quality:
# Boxplot for volatile acidity versus quality:
# Boxplot for citric acid versus quality:
# Boxplot for residual sugar versus quality:
# Boxplot for chlorides versus quality:
# Boxplot for free sulfur dioxide versus quality:
# Boxplot for total sulfur dioxide versus quality:
# Boxplot for density versus quality:
# Boxplot for pH versus quality:
# Boxplot for sulphates versus quality:
# Boxplot for alcohol versus quality:
